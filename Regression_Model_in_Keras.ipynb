# %% [markdown]
# # Concrete Compressive Strength Prediction Using Keras

# %%
import keras 
import numpy as np 
import pandas as pd 
from keras.layers import Dense
from keras.layers import Input
from keras.models import Sequential
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("concrete_data.csv")
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  Coarse Aggregate  Fine Aggregate  Age  Strength
# 0   540.0                 0.0      0.0  162.0               2.5            1040.0           676.0   28     79.99
# 1   540.0                 0.0      0.0  162.0               2.5            1055.0           676.0   28     61.89
# 2   332.5               142.5      0.0  228.0               0.0             932.0           594.0  270     40.27
# 3   332.5               142.5      0.0  228.0               0.0             932.0           594.0  365     41.05
# 4   198.6               132.4      0.0  192.0               0.0             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash  ...  Fine Aggregate          Age     Strength
# count  1030.000000         1030.000000  1030.000000  ...     1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350  ...      773.580485    45.662136    35.817961
# std     104.506364           86.279342    63.997004  ...       80.175980    63.169912    16.705742
# min     102.000000            0.000000     0.000000  ...      594.000000     1.000000     2.330000
# 25%     192.375000            0.000000     0.000000  ...      730.950000     7.000000    23.710000
# 50%     272.900000           22.000000     0.000000  ...      779.500000    28.000000    34.445000
# 75%     350.000000          142.950000   118.300000  ...      824.000000    56.000000    46.135000
# max     540.000000          359.400000   200.100000  ...      992.600000   365.000000    82.600000
#
# [8 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
data_cols = data.columns
data_cols
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
X = data[data_cols[data_cols != "Strength"]]
y = data["Strength"]

# %%
X.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  Coarse Aggregate  Fine Aggregate  Age
# 0   540.0                 0.0      0.0  162.0               2.5            1040.0           676.0   28
# 1   540.0                 0.0      0.0  162.0               2.5            1055.0           676.0   28
# 2   332.5               142.5      0.0  228.0               0.0             932.0           594.0  270
# 3   332.5               142.5      0.0  228.0               0.0             932.0           594.0  365
# 4   198.6               132.4      0.0  192.0               0.0             978.4           825.5  360

# %%
y.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
X_norm = (X - X.mean()) / X.std()
X_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  Coarse Aggregate  Fine Aggregate       Age
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147          0.862735       -1.217079 -0.279597
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147          1.055651       -1.217079 -0.279597
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638         -0.526262       -2.239829  3.551340
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638         -0.526262       -2.239829  5.055221
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638          0.070492        0.647569  4.976069

# %%
no_cols = X_norm.shape[1]
no_cols
# Out:
# 8

# %%
X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=42)

# %%
def regression_model():

    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(no_cols,)))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
# Out:
# C:\Users\mhasn\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 1s - 45ms/step - loss: 1537.4044
# Epoch 2/50
# 23/23 - 0s - 5ms/step - loss: 1520.5564
# Epoch 3/50
# 23/23 - 0s - 4ms/step - loss: 1503.5354
# Epoch 4/50
# 23/23 - 0s - 4ms/step - loss: 1485.8958
# Epoch 5/50
# 23/23 - 0s - 4ms/step - loss: 1467.3213
# Epoch 6/50
# 23/23 - 0s - 4ms/step - loss: 1447.7373
# Epoch 7/50
# 23/23 - 0s - 4ms/step - loss: 1426.7080
# Epoch 8/50
# 23/23 - 0s - 4ms/step - loss: 1404.7122
# Epoch 9/50
# 23/23 - 0s - 4ms/step - loss: 1381.3413
# Epoch 10/50
# 23/23 - 0s - 4ms/step - loss: 1356.7534
# Epoch 11/50
# 23/23 - 0s - 3ms/step - loss: 1331.2506
# Epoch 12/50
# 23/23 - 0s - 4ms/step - loss: 1304.0234
# Epoch 13/50
# 23/23 - 0s - 4ms/step - loss: 1276.0422
# Epoch 14/50
# 23/23 - 0s - 4ms/step - loss: 1246.6016
# Epoch 15/50
# 23/23 - 0s - 4ms/step - loss: 1216.2937
# Epoch 16/50
# 23/23 - 0s - 5ms/step - loss: 1185.1249
# Epoch 17/50
# 23/23 - 0s - 6ms/step - loss: 1153.1625
# Epoch 18/50
# 23/23 - 0s - 5ms/step - loss: 1120.0385
# ...

# %%
loss_val = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
loss_val
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 297.1758
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 297.2012023925781

# %%
mse = mean_squared_error(y_test, pred)
mse_mean = np.mean(mse)
sd = np.std(mse)
print(f"Mean : {mse_mean}, Standard Deviation: {sd}")
# Out:
# Mean : 297.2012036379088, Standard Deviation: 0.0

# %%
total_mse = 50
mean_squared_errors = []
for i in range(0, total_mse):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=50, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print(f"MSE {i+1}: {MSE}")
    pred = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, pred)
    mean_squared_errors.append(mean_square_error)
    

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
sd = np.std(mean_squared_errors)

print(f"\n\nMean of All Mean Square Error is : {mean} \nStandard Deviation of All Mean Square Error is: {sd}")
# Out:
# MSE 1: 15559.177734375
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 2: 5254.34375
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 3: 3435.67626953125
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 4: 2349.582275390625
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE 5: 892.9915161132812
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 6: 301.727294921875
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 7: 159.60775756835938
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 8: 115.06407928466797
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 9: 125.26402282714844
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 10: 113.04066467285156
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE 11: 110.0464859008789
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 12: 102.70885467529297
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 13: 113.69451904296875
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 14: 120.32723999023438
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 15: 108.89230346679688
# ...

# %% [markdown]
# ### Increase The Number Of Hidden Layers

# %%
def regression_model():

    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(no_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = regression_model()
# Out:
# C:\Users\mhasn\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 2s - 83ms/step - loss: 5772.3691
# Epoch 2/50
# 23/23 - 0s - 5ms/step - loss: 651.1428
# Epoch 3/50
# 23/23 - 0s - 7ms/step - loss: 482.7576
# Epoch 4/50
# 23/23 - 0s - 4ms/step - loss: 423.5342
# Epoch 5/50
# 23/23 - 0s - 4ms/step - loss: 380.4141
# Epoch 6/50
# 23/23 - 0s - 3ms/step - loss: 328.6416
# Epoch 7/50
# 23/23 - 0s - 4ms/step - loss: 273.7595
# Epoch 8/50
# 23/23 - 0s - 4ms/step - loss: 232.4857
# Epoch 9/50
# 23/23 - 0s - 5ms/step - loss: 215.5161
# Epoch 10/50
# 23/23 - 0s - 5ms/step - loss: 204.7427
# Epoch 11/50
# 23/23 - 0s - 5ms/step - loss: 195.5516
# Epoch 12/50
# 23/23 - 0s - 6ms/step - loss: 186.7400
# Epoch 13/50
# 23/23 - 0s - 7ms/step - loss: 177.6156
# Epoch 14/50
# 23/23 - 0s - 7ms/step - loss: 170.3989
# Epoch 15/50
# 23/23 - 0s - 5ms/step - loss: 163.2736
# Epoch 16/50
# 23/23 - 0s - 6ms/step - loss: 154.7880
# Epoch 17/50
# 23/23 - 0s - 7ms/step - loss: 149.1762
# Epoch 18/50
# 23/23 - 0s - 6ms/step - loss: 142.3403
# Epoch 19/50
# ...

# %%
loss_val = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
loss_val
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.8943
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 79.22079467773438

# %%
mse = mean_squared_error(y_test, pred)
mse_mean = np.mean(mse)
sd = np.std(mse)
print(f"Mean : {mse_mean}, Standard Deviation: {sd}")
# Out:
# Mean : 79.22079159700358, Standard Deviation: 0.0

# %%
total_mse = 50
mean_squared_errors = []
for i in range(0, total_mse):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=50, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print(f"MSE {i+1}: {MSE}")
    pred = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, pred)
    mean_squared_errors.append(mean_square_error)
    

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
sd = np.std(mean_squared_errors)

print(f"\n\nMean of All Mean Square Error is : {mean} \nStandard Deviation of All Mean Square Error is: {sd}")
# Out:
# MSE 1: 59.68658447265625
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 2: 70.3816146850586
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 3: 49.37305450439453
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 4: 63.98674011230469
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 5: 54.72098922729492
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 6: 54.58715057373047
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 7: 84.1673355102539
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 8: 43.92060852050781
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 9: 44.24623107910156
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 10: 51.92610549926758
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 11: 43.65580749511719
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 12: 39.5606575012207
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MSE 13: 53.076934814453125
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE 14: 45.392356872558594
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 15: 45.1142463684082
# ...
